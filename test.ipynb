# %%
import etl
etl.main()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-13-d0a811721375> in <module>()
#       1 import etl
# ----> 2 etl.main()
#
# /home/workspace/etl.py in main()
#     106     output_data = "s3a://mengheng-s3/"
#     107
# --> 108     process_song_data(spark, input_data, output_data)
#     109     process_log_data(spark, input_data, output_data)
#     110
#
# /home/workspace/etl.py in process_song_data(spark, input_data, output_data)
#      27
#      28     # read song data file
# ---> 29     df = spark.read.json(song_data)
#      30
#      31     # extract columns to create songs table
#
# ...
